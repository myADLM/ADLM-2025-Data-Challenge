# %% [markdown]
# # SOP Query Notebook
#
# ## Environment Setup
#
# This notebook uses the `.venvChallengeProd` virtual environment located in the `prod` directory.
#
# ### To activate the environment in terminal:
# ```bash
# cd /labs/jupyter/ai_challenge/prod
# source .venvChallengeProd/bin/activate
# ```
#
# ### To run Python directly with this environment:
# ```bash
# /labs/jupyter/ai_challenge/prod/.venvChallengeProd/bin/python your_script.py
# ```
#
# ### To select the correct kernel in VS Code:
# 1. Click on the kernel selector in the top right of the notebook
# 2. Select "Python Environments..."
# 3. Choose the Python interpreter from: `/labs/jupyter/ai_challenge/prod/.venvChallengeProd/bin/python`
#
# ### Installed packages:
# - langchain ✅
# - langgraph ✅
# - requests ✅
# - All required dependencies ✅
#
# **Environment is ready to use!**

# %%
VERBOSE_MODE = True

import sys
from pathlib import Path
sys.path.append(str(Path('../modules')))

from langchain.agents import Tool
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.llms.base import LLM

from langchain_core.messages import HumanMessage
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import START, MessagesState, StateGraph, END

import requests
import base64
import os, json, inspect
import importlib

from typing import Literal, Optional, List, Mapping, Any, Dict, Tuple
from northwellllm import NorthwellLLM

# Reload the SOPQuery module to get the latest changes
import SOPQuery
importlib.reload(SOPQuery)
from SOPQuery import SOPQuery

sop_dir = Path('../LabDocs/es1/sop')
sops = []
i = 0
for f in sop_dir.glob('*.json'):
    json_content = f.read_text(encoding='utf-8')
    sops.append((i, f.name, json_content))
    i += 1

print(f"Loaded {len(sops)} SOPs")
#print(sops)
# Out:
# Loaded 4254 SOPs

# %%
# Comprehensive SOP Query Test - Sample Questions
sample_questions = [
    "does calcium have a reference range?",
    "I have just received an green-top tube for a1c?",
    "what is the reference range for prothrombin time?",
    "I'm worried there is a typo in an SOP; I need to compare the reference ranges for PT",
    "How can i check if a patient is pregnant?",
    "what is the critical value for mg?",
    "what is the ref range for mg?",
    "I just got a mg on my patient of 3?",
    "I just received an addon request for an a1c, and I see a specimen in my lab from Sunday",
    "I just received an addon request for an a1c, and I see a bmp in my lab from Sunday?",
    "I just received an addon request for an a1c, and I see a wbc cell count in my lab from Sunday?",
    "what tests can I run on ffpe?",
    "what tests need consent?",
    "what tests can I run on urine?",
    "what tests can I run on csf?",
    "what genetic tests are available",
    "what tests are done on lavendar tubes",
    "what tests are done on royal blue tubes?",
    "I am concerned about metal poisoning"
    
]


_sample_questions = [
        "How can i check if a patient is pregnant??"
]

print(f"Testing {len(sample_questions)} sample questions...")
print("=" * 80)

for i, question in enumerate(sample_questions, 1):
    print(f"\n🔍 QUESTION {i}/{len(sample_questions)}:")
    print(f"Q: {question}")
    print("-" * 60)
    
    try:
        sop_query = SOPQuery(debug=0)
        res, history = sop_query.ask_sop(question, sops)  # Fixed: added sops parameter
        print(f"{res}")
    except Exception as e:
        print(f"❌ ERROR: {e}")
    
    print("=" * 80)
# Out:
# Testing 19 sample questions...
# ================================================================================
#
# 🔍 QUESTION 1/19:
# Q: does calcium have a reference range?
# ------------------------------------------------------------
# Starting time: 1762962066.8358815
# Enhanced question: What are the reference (normal) ranges for total and ionized serum calcium testing? LIKELY SOP: Serum/Plasma Calcium (Total and Ionized)
# Time after enhancing question: 1762962069.7882805 (Elapsed: 2.95s)
# Time after identifying relevant documents: 1762962094.9839852 (Elapsed: 28.15s)
# Time after finding document excerpts: 1762962104.5892596 (Elapsed: 37.75s)
# Time after synthesizing sources: 1762962122.364605 (Elapsed: 55.53s)
# Time after making llm pretty: 1762962128.4499433 (Elapsed: 61.61s)
# Evaluating answer quality...
# Time after evaluating answer quality: 1762962131.360059 (Elapsed: 64.52s)
# Answer quality satisfactory, proceeding to format the answer.
# Q: What are the normal (reference) ranges for total and ionized calcium in serum?
#
# A:
# • Total serum calcium: 8.5 – 10.2 mg/dL (2.12 – 2.55 mmol/L)
# • Ionized serum calcium: 1.12 – 1.32 mmol/L
#
# Why: These values represent the standard adult reference intervals used to judge whether a patient’s calcium level is within the expected physiological range. Staying within these limits is important for proper neuromuscular and metabolic function; values outside them may signal endocrine, renal, or metabolic disorders.
#
# Refs:
# 1. CALCIUM_TOTAL_SERUM_es1 – “Normal range for serum calcium: 8.5-10.2 mg/dL (2.12-2.55 mmol/L)”
# 2. CALCIUM_IONIZED_BLOOD_es1 – “Adults: 1.12 – 1.32 mmol/L (ionized calcium)”
# ================================================================================
#
# 🔍 QUESTION 2/19:
# Q: I have just received an green-top tube for a1c?
# ------------------------------------------------------------
# Starting time: 1762962131.3619263
# Enhanced question: What are the specimen collection and acceptability requirements for Hemoglobin A1C testing, and is a green-top (lithium heparin) tube acceptable? LIKELY SOP: Hemoglobin A1C
# Time after enhancing question: 1762962134.3974404 (Elapsed: 3.04s)
# Time after identifying relevant documents: 1762962150.9044662 (Elapsed: 19.54s)
# Time after finding document excerpts: 1762962157.229189 (Elapsed: 25.87s)
# Time after synthesizing sources: 1762962157.2293239 (Elapsed: 25.87s)
# Time after making llm pretty: 1762962162.1563354 (Elapsed: 30.79s)
# Evaluating answer quality...
# Time after evaluating answer quality: 1762962166.046095 (Elapsed: 34.68s)
# Answer quality satisfactory, proceeding to format the answer.
# 1) Q: What tubes and handling requirements are acceptable for Hemoglobin A1c testing, and can we use a green-top (lithium-heparin) tube?
#
# 2) A: Submit whole blood in a properly labeled lavender-top (EDTA) tube only. Green-top (lithium-heparin) tubes are NOT acceptable.
#
# 3) Why: The HbA1c SOP lists EDTA whole-blood specimens as the sole acceptable sample type. It also rejects hemolyzed, clotted, mislabeled, or improperly stored/transported samples; green-top tubes are not mentioned and are therefore excluded.
#
# 4) Refs:
# • HEMOGLOBIN_A1C_BLOOD_es1 – “Acceptable Specimens: • Whole blood collected in EDTA (lavender-top) tubes… Unacceptable Specimens: • Hemolyzed samples • Clotted samples • Samples not stored or transported at proper temperatures • Specimens without proper labeling.”
# • Same document – “Acceptable Specimens: • Whole blood collected in EDTA (lavender-top) tubes.”
# ================================================================================
#
# 🔍 QUESTION 3/19:
# Q: what is the reference range for prothrombin time?
# ------------------------------------------------------------
# Starting time: 1762962166.0476596
# Enhanced question: What is the reference (normal) range for Prothrombin Time (PT) coagulation testing? LIKELY SOP: Prothrombin Time (PT) / Coagulation
# Time after enhancing question: 1762962168.4003227 (Elapsed: 2.35s)
# Time after identifying relevant documents: 1762962186.7000394 (Elapsed: 20.65s)
# Time after finding document excerpts: 1762962192.9790866 (Elapsed: 26.93s)
# Time after synthesizing sources: 1762962221.9939082 (Elapsed: 55.95s)
# Time after making llm pretty: 1762962227.6630542 (Elapsed: 61.62s)
# Evaluating answer quality...
# Time after evaluating answer quality: 1762962230.4347203 (Elapsed: 64.39s)
# Answer quality satisfactory, proceeding to format the answer.
# Q: What is the reference (normal) range for Prothrombin Time (PT) coagulation testing?
#
# A: Most SOPs place the normal PT between roughly 10 – 14 seconds (commonly 11 – 13.5 s). Always default to your laboratory’s validated reference interval.
#
# Why: Multiple procedure manuals show overlapping normal ranges in the 10–14 s window; however, several explicitly state that each lab must use its own lot- and instrument-specific range.
#
# Refs:
# • PROTHROMBIN_TIME_PT_PLASMA_es1 – “PT: 10-14 seconds (may vary…).”
# • PROTHROMBIN_TIME_PT_50_50_MIX_PLASMA_es1 – “PT: 11-13.5 seconds (or as per laboratory standard).”
# • PROTHROMBIN_TIME_PLASMA_es1 – “Normal Range: 11-14 seconds.”
# • PROTHROMBIN_TIME_MIX_1_1_PLASMA_es1 – “Refer to laboratory-specific reference intervals for PT.”
# • PROLONGED_CLOT_TIME_PROFILE_PLASMA_es1 – “Normal reference ranges: Refer to site-specific reference intervals.”
# ================================================================================
#
# 🔍 QUESTION 4/19:
# Q: I'm worried there is a typo in an SOP; I need to compare the reference ranges for PT
# ------------------------------------------------------------
# Starting time: 1762962230.4363356
# Enhanced question: What are the reference ranges for Prothrombin Time (PT/INR) testing? Are there any typos or discrepancies in the PT reference range values stated in the SOP? LIKELY SOP: Prothrombin Time (PT/INR)
# Time after enhancing question: 1762962240.4703693 (Elapsed: 10.03s)
# JSON parsing error in _identify_relevant_documents_batch: Expecting property name enclosed in double quotes: line 1 column 282 (char 281)
# Response:  {"function":"_identify_relevant_documents_batch","primary_question":"What are the reference ranges for Prothrombin Time (PT/INR) testing? Are there any typos or discrepancies in the PT reference range values stated in the SOP? LIKELY SOP: Prothrombin Time (PT/INR)","documents":[{No documents exceeded the relevance threshold of 0.75 for the specific question regarding reference ranges for routine Prothrombin Time (PT/INR) testing.}]}

# %%
# Reload the SOPQuery module to get the latest changes
import SOPQuery
importlib.reload(SOPQuery)
from SOPQuery import SOPQuery

question = "I'm worried there is a typo in an SOP; I need to compare the reference ranges for PT"
try:
    sop_query = SOPQuery(debug=0)
    res = sop_query.enhance_query_with_llm(question)  # Fixed: added sops parameter
    print(f"{res}")
except Exception as e:
    print(f"❌ ERROR: {e}")

print("=" * 80)
# Out:
# What are the reference ranges for Prothrombin Time (PT) testing? Are there any typographical errors or discrepancies in the PT reference range data presented in the SOP? LIKELY SOP: Prothrombin Time (PT)
# ================================================================================

# %%
# Reload the SOPQuery module to get the latest changes
import SOPQuery
importlib.reload(SOPQuery)
from SOPQuery import SOPQuery

question = "I'm worried there is a typo in an SOP; I need to compare the reference ranges for PT"
try:
    sop_query = SOPQuery(debug=0)
    res = sop_query.enhance_query_with_llm(question, model='gpt-4o')  # Fixed: added sops parameter
    print(f"{res}")
except Exception as e:
    print(f"❌ ERROR: {e}")

print("=" * 80)
# Out:
# What are the reference ranges for Prothrombin Time (PT) testing? Are there any typographical errors in the reference ranges provided for PT in the SOP? LIKELY SOP: Prothrombin Time (PT)
# ================================================================================

# %%
# Reload the SOPQuery module to get the latest changes
import SOPQuery
importlib.reload(SOPQuery)
from SOPQuery import SOPQuery

question = "I'm worried there is a typo in an SOP; I need to compare the reference ranges for PT"
try:
    sop_query = SOPQuery(debug=0)
    res, history = sop_query.ask_sop(question, sops)  # Fixed: added sops parameter
    print(f"{res}")
except Exception as e:
    print(f"❌ ERROR: {e}")

print("=" * 80)
# Out:
# Starting time: 1758830123.4005234
# Enhanced question: What are the reference ranges for Prothrombin Time (PT) testing? What, if any, typographical errors exist in those reference range values? LIKELY SOP: Prothrombin Time (PT)
# Time after enhancing question: 1758830126.217073 (Elapsed: 2.82s)
# Time after identifying relevant documents: 1758830170.9363184 (Elapsed: 47.54s)
# Time after finding document excerpts: 1758830195.7646956 (Elapsed: 72.36s)
# Time after synthesizing sources: 1758830204.433178 (Elapsed: 81.03s)
# Time after making llm pretty: 1758830207.873869 (Elapsed: 84.47s)
# Evaluating answer quality...
# Time after evaluating answer quality: 1758830210.8942919 (Elapsed: 87.49s)
# Answer quality satisfactory, proceeding to format the answer.
# 1) Q: What are the normal reference ranges for Prothrombin Time (PT) testing, and do those published values contain any typos?
#
# 2) A:
#    • PT: 11 – 13.5 seconds
#    • INR (patients not receiving anticoagulants): 0.8 – 1.2
#    No typographical errors were found in these values.
#
# 3) Why: These ranges are taken directly from the cited SOP section on reference intervals and are internally consistent (e.g., decimals are placed correctly, units are given, ranges are plausible).
#
# 4) Refs:
#    • PROTHROMBIN_TIME_PT_50_50_MIX_PLASMA_es1 – “9. REFERENCE INTERVALS • PT: 11-13.5 seconds (or as per laboratory standard) • INR: 0.8-1.2 (for patients not on anticoagulant therapy)”
# ================================================================================

# %%
question = "I'm worried there is a typo in an SOP; I need to compare the reference ranges for PT"
synthesized_results = """
Synthesized results: {'function': 'synthesize_multiple_sources', 'primary_question': 'What are the reference ranges and normal values for Prothrombin Time (PT) testing in the laboratory SOP, so I can verify a possible typographical error? LIKELY SOP: Coagulation – Prothrombin Time (PT)', 'results': [{'question': 'What are the reference ranges and normal values for Prothrombin Time (PT) testing in the laboratory SOP?', 'answer': 'PT reference interval: 11–13.5 seconds; INR normal range: 0.8–1.2 (for patients not on anticoagulant therapy).', 'document': 'PROTHROMBIN_TIME_PT_50_50_MIX_PLASMA_es1', 'excerpt': '9. REFERENCE INTERVALS\n• PT: 11-13.5 seconds (or as per laboratory standard)\n• INR: 0.8-1.2 (for patients not on anticoagulant therapy)', 'relevance_level': '1.0'}, {'question': 'What are the reference ranges and normal values for Prothrombin Time (PT) testing in the laboratory SOP?', 'answer': 'According to the SOP, PT: 10–14 seconds; INR: 0.8–1.2 for non-anticoagulated patients.', 'document': 'PROTHROMBIN_TIME_PT_PLASMA_es1', 'excerpt': 'D) Result Interpretation\n2. Reference Ranges:\n▪ PT: 10-14 seconds (may vary depending on method and reagents, refer to specific laboratory reference interval).\n▪ INR: 0.8-1.2 for non-anticoagulated patients.', 'relevance_level': '1.0'}, {'question': 'What are the reference ranges and normal values for Prothrombin Time (PT) testing according to the laboratory SOP?', 'answer': 'The SOP does not specify a numeric PT reference range; it instructs users to "Refer to manufacturer’s guidance or laboratory-defined reference ranges."', 'document': 'PT-FIBRINOGEN_PLASMA_es1', 'excerpt': 'Reference Intervals:\n• PT: Refer to manufacturer’s guidance or laboratory-defined reference ranges.', 'relevance_level': '1.0'}, {'question': 'What are the reference ranges and normal values for Prothrombin Time (PT) testing in the laboratory SOP?', 'answer': 'The SOP does not list numeric PT reference ranges; it only directs staff to perform the test and record the clotting time.', 'document': 'PROLONGED_CLOT_TIME_PROFILE_INTERPRETATION_es1', 'excerpt': '6.1. Initial Testing • Prothrombin Time (PT) □ Follow the manufacturer’s instructions for the PT reagent and equipment. □ Document the time it takes for the clot to form in seconds.', 'relevance_level': '1.0'}, {'question': 'What are the reference ranges and normal values for Prothrombin Time (PT) testing in the laboratory SOP?', 'answer': 'The SOP provides no numeric PT reference values, instructing users to consult their own laboratory-specific reference intervals.', 'document': 'PROTHROMBIN_TIME_MIX_1_1_PLASMA_es1', 'excerpt': '9. Reference Intervals:\n• Refer to laboratory-specific reference intervals for PT. Typically, PT is provided with a reference interval for normal plasma based on laboratory calibrations and analyzer specifications.', 'relevance_level': '1.0'}]}
"""
#test evaluate_answer_quality(enhanced_question, synthesized_results)
try:
    sop_query = SOPQuery(debug=0)
    # Simulate the pre-final step with synthesized results
    evaluation = sop_query.evaluate_answer_quality(question, synthesized_results)
    print(f"{evaluation}")
except Exception as e:
    print(f"❌ ERROR: {e}")
# Out:
# satisfactory

# %%
# Reload the SOPQuery module to get the latest changes
import SOPQuery
importlib.reload(SOPQuery)
from SOPQuery import SOPQuery

question = "I'm worried there is a typo in an SOP; I need to compare the reference ranges for PT"
synthesized_results = """
1) Q:  
What PT reference (normal) ranges does the “Coagulation – Prothrombin Time (PT)” SOP give, so we can rule out a typo?

2) A:  
• PT: 10-14 seconds (most often written 11-13.5 s)  
• INR (if reported): 0.8-1.2 for patients not on anticoagulant therapy  
(Some SOP versions do not print numbers and instead tell you to use the manufacturer’s or your own laboratory-validated ranges.)

3) Why:  
Out of the five SOP versions retrieved, two list essentially the same numeric range (10-14 s or 11-13.5 s). The other three omit numbers and direct staff to local ranges. Because the two numeric versions agree and fall within the typical PT range found in textbooks, they are probably what the author meant; a value far outside 10-14 s is likely a typographical error.

4) Refs:  
• “PROTHROMBIN_TIME_PT_50_50_MIX_PLASMA_es1” – “PT: 11-13.5 seconds … INR: 0.8-1.2”  
• “PROTHROMBIN_TIME_PT_PLASMA_es1” – “PT: 10-14 seconds … INR: 0.8-1.2”  
• “PT-FIBRINOGEN_PLASMA_es1” – “PT: Refer to manufacturer’s guidance or laboratory-defined reference ranges.”  
• “PROLONGED_CLOT_TIME_PROFILE_INTERPRETATION_es1” – no numeric range; instructs to record clotting time per reagent instructions.  
• “PROTHROMBIN_TIME_MIX_1_1_PLASMA_es1” – “Refer to laboratory-specific reference intervals for PT.”
"""

synthesized_results_new = """
Q: What are the normal reference ranges for Prothrombin Time (PT) and are there any typos or conflicting values in the SOP?

A:  
• PT: 10–14 seconds  
• INR (patients not on anticoagulants): 0.8–1.2  
There are no typographical errors or conflicting values; the SOP states these ranges consistently.

Why: Knowing the correct PT/INR reference limits is essential for spotting clotting abnormalities. The SOP lists the same numbers every time, so the lab can trust the intervals shown.

Refs:  
PROTHROMBIN_TIME_PT_PLASMA_es1 – Section “Result Interpretation, Reference Ranges”:  
“PT: 10-14 seconds (may vary depending on method and reagents)… INR: 0.8-1.2 for non-anticoagulated patients.”"""
#test evaluate_answer_quality(enhanced_question, synthesized_results)
try:
    sop_query = SOPQuery(debug=0)
    # Simulate the pre-final step with synthesized results
    # evaluation = sop_query.evaluate_answer_quality(question, synthesized_results_new, model='gpt-4o')
    evaluation = sop_query.evaluate_answer_quality(question, synthesized_results_new, model='o3')

    print(f"{evaluation}")
except Exception as e:
    print(f"❌ ERROR: {e}")
# Out:
# satisfactory
#
# The response supplies the commonly accepted PT reference range (10–14 s) and corresponding INR range, giving the user figures with which to compare their SOP. Although the answer also asserts that the SOP has no typo—something it cannot truly verify without seeing the user’s document—it still fulfills the primary need by stating the standard reference ranges, so the user can perform the comparison themselves.

# %%
# Debug single question to isolate the error
print("🔍 DEBUG: Testing single question with detailed tracing...")

question = "Can i test if im allergic to cockaroaches?"
print(f"Question: {question}")

try:
    # Step 1: Create SOPQuery instance
    print("Step 1: Creating SOPQuery instance...")
    sop_query = SOPQuery(debug=1)
    print("✅ SOPQuery created successfully")
    
    # Step 2: Enhanced question
    print("Step 2: Enhancing question...")
    enhanced_question = sop_query.enhance_query_with_llm(question)
    print(f"✅ Enhanced question: {enhanced_question}")
    
    # Step 3: Identify relevant documents
    print("Step 3: Identifying relevant documents...")
    documents = sop_query.identify_relevant_documents(enhanced_question, sops)
    print(f"✅ Documents response type: {type(documents)}")
    print(f"✅ Documents keys: {documents.keys() if isinstance(documents, dict) else 'Not a dict'}")

    
    if 'error' in documents:
        print(f"❌ Error in documents: {documents['error']}")
        print(f"❌ Error in documents: {documents['raw_error']}")
    elif 'documents' not in documents:
        print(f"❌ No documents key found. Response: {documents}")
    elif not documents['documents'] or len(documents['documents']) == 0:
        print("❌ No relevant documents found")
    else:
        print(f"✅ Found {len(documents['documents'])} relevant documents")
        
        # Step 4: Process documents (first one only for debug)
        print("Step 4: Processing first document...")
        document = documents['documents'][0]
        sop = sops[int(document['doc_id'])]
        print(f"✅ Processing document: {sop[1]}")
        
        # Convert filename and read content
        txt_filename = sop[1].replace('.json', '.txt').replace('_es1', '')
        txt_path = f'../LabDocs/extracted_txts/{txt_filename}'
        print(f"✅ Looking for file: {txt_path}")
        
        with open(txt_path, 'r', encoding='utf-8') as file:
            sop_content = file.read()
        print(f"✅ File content length: {len(sop_content)} characters")
        
        # Step 5: Find document excerpts
        print("Step 5: Finding document excerpts...")
        doc_excerpt = sop_query.find_document_excerpts(enhanced_question, sop_content, sop[1][:-5])
        print(f"✅ Doc excerpt type: {type(doc_excerpt)}")
        print(f"✅ Doc excerpt keys: {doc_excerpt.keys() if isinstance(doc_excerpt, dict) else 'Not a dict'}")
        
        doc_excerpts = [json.dumps(doc_excerpt)]
        
        # Step 6: Make pretty result
        print("Step 6: Making pretty result...")
        pretty_result = sop_query.make_llm_pretty(enhanced_question, doc_excerpts)
        print(f"✅ Pretty result type: {type(pretty_result)}")
        print(f"✅ Pretty result: {pretty_result}")
        
except Exception as e:
    print(f"❌ ERROR occurred at step: {e}")
    import traceback
    traceback.print_exc()
# Out:
# 🔍 DEBUG: Testing single question with detailed tracing...
# Question: Can i test if im allergic to cockaroaches?
# Step 1: Creating SOPQuery instance...
# ✅ SOPQuery created successfully
# Step 2: Enhancing question...
# What laboratory tests are available to detect a patient’s allergy to cockroach allergens, and what are the associated specimen collection and handling requirements? LIKELY SOP: Specific IgE Allergen Testing – Cockroach
# ✅ Enhanced question: What laboratory tests are available to detect a patient’s allergy to cockroach allergens, and what are the associated specimen collection and handling requirements? LIKELY SOP: Specific IgE Allergen Testing – Cockroach
# Step 3: Identifying relevant documents...
# Processing 3995 documents in batches of 1000
# Processing batch 1/4 (1000 documents)
#
# Processing batch 2/4 (1000 documents)
#
# Processing batch 3/4 (1000 documents)
#
# Processing batch 4/4 (995 documents)
# "doc_id":"3169", "doc_name":"COCKROACH_IGE_SERUM_es1.json", "relevance_level":"0.95"
# "doc_id":"3230", "doc_name":"COCKROACH_AMERICAN_PERIPLANETA_AMERICANA_IGE_es1.json", "relevance_level":"0.90"
# Batch 4: Found 2 relevant documents
# Total relevant documents found: 2
# ✅ Documents response type: <class 'dict'>
# ✅ Documents keys: dict_keys(['function', 'primary_question', 'documents', 'total_batches', 'total_documents_processed', 'total_relevant_found'])
# ✅ Found 2 relevant documents
# Step 4: Processing first document...
# ✅ Processing document: COCKROACH_IGE_SERUM_es1.json
# ✅ Looking for file: ../LabDocs/extracted_txts/COCKROACH_IGE_SERUM.txt
# ✅ File content length: 4903 characters
# Step 5: Finding document excerpts...
# "question":"What laboratory test is available to detect a patient’s allergy to cockroach allergens?", "answer":"The available laboratory test is the Cockroach allergen–specific serum IgE assay (listed in the SOP as “COCKROACH, IGE, SERUM”).", "document":"COCKROACH_IGE_SERUM_es1", "excerpt":"1. DEFINITION The COCKROACH, IGE, SERUM test quantifies serum immunoglobulin E (IgE) antibodies specific to cockroach allergens. The test is used to aid in the diagnosis of allergic reactions to cockroach allergens.", "relevance_level":"1"
#
# "question":"What are the specimen collection and handling requirements for this cockroach-specific IgE test?", "answer":"• Collect 1 mL (minimum) of serum in an SST (serum separator tube) or red-top tube.  • Centrifuge and separate serum within 2 hours of collection; aliquot into a clean, labeled tube if needed.  • Acceptable only if non-hemolyzed, non-lipemic, non-icteric, and without anticoagulant.  • Unacceptable if volume is insufficient, if received >72 h unrefrigerated, or >7 days refrigerated.  • Store/transport refrigerated if analysis is delayed.", "document":"COCKROACH_IGE_SERUM_es1", "excerpt":"A. Specimen Requirements Preferred/Acceptable: • Serum collected in an SST (serum separator tube) or red-top tube. • Minimum volume: 1 mL of serum. • Specimens must be centrifuged and the serum separated within 2 hours of collection. • Aliquot serum into a clean, labeled tube for analysis if needed. Unacceptable: • Hemolyzed, lipemic, or icteric samples. • Specimens submitted in tubes containing anticoagulants. • Samples with insufficient volume. • Specimens received more than 72 hours post-collection if not refrigerated; specimens received more than 7 days post-collection if refrigerated.", "relevance_level":"1"
# ✅ Doc excerpt type: <class 'dict'>
# ✅ Doc excerpt keys: dict_keys(['function', 'primary_question', 'results'])
# Step 6: Making pretty result...
# Q: What lab test is used to check if a patient is allergic to cockroach allergens, and what specimen rules apply?
#
# A: Order the “COCKROACH, IgE, SERUM” test (cockroach-specific serum IgE).
#    • Tube: SST (gold) or plain red-top.
#    • Volume: ≥ 1 mL serum.
#    • Processing: Spin and separate serum within 2 hours; transfer to a labeled aliquot tube if needed.
#    • Transport/Storage: Keep refrigerated if the assay cannot be run immediately.
#    • Rejection criteria: hemolyzed, lipemic, icteric, or anticoagulated samples; < 1 mL volume; unrefrigerated > 72 h; refrigerated > 7 days.
#
# Why: The test measures IgE antibodies directed against cockroach proteins, helping confirm an IgE-mediated allergy. Correct collection and timely separation keep the serum stable and prevent false results.
#
# Refs:
# 1. COCKROACH_IGE_SERUM_es1 – “The COCKROACH, IGE, SERUM test quantifies serum IgE antibodies specific to cockroach allergens…”
# 2. COCKROACH_IGE_SERUM_es1 – Specimen requirements: “Serum in SST or red-top; minimum 1 mL; centrifuge and separate within 2 h; reject hemolyzed/lipemic/icteric or anticoagulated samples; store refrigerated ≤ 7 days or ≤ 72 h at room temp.”
# ✅ Pretty result type: <class 'str'>
# ✅ Pretty result: Q: What lab test is used to check if a patient is allergic to cockroach allergens, and what specimen rules apply?
#
# A: Order the “COCKROACH, IgE, SERUM” test (cockroach-specific serum IgE).
#    • Tube: SST (gold) or plain red-top.
#    • Volume: ≥ 1 mL serum.
#    • Processing: Spin and separate serum within 2 hours; transfer to a labeled aliquot tube if needed.
#    • Transport/Storage: Keep refrigerated if the assay cannot be run immediately.
#    • Rejection criteria: hemolyzed, lipemic, icteric, or anticoagulated samples; < 1 mL volume; unrefrigerated > 72 h; refrigerated > 7 days.
#
# Why: The test measures IgE antibodies directed against cockroach proteins, helping confirm an IgE-mediated allergy. Correct collection and timely separation keep the serum stable and prevent false results.
#
# Refs:
# 1. COCKROACH_IGE_SERUM_es1 – “The COCKROACH, IGE, SERUM test quantifies serum IgE antibodies specific to cockroach allergens…”
# 2. COCKROACH_IGE_SERUM_es1 – Specimen requirements: “Serum in SST or red-top; minimum 1 mL; centrifuge and separate within 2 h; reject hemolyzed/lipemic/icteric or anticoagulated samples; store refrigerated ≤ 7 days or ≤ 72 h at room temp.”
